# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df_diabetes = df[ df["diabetes"] == 1]
df_diabetes
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6      Female  44.0             0              0           never  19.31
# 26       Male  67.0             0              1     not current  27.32
# 38       Male  50.0             1              0         current  27.32
# 40       Male  73.0             0              0          former  25.91
# 53     Female  53.0             0              0          former  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99935  Female  65.0             1              1           never  33.55
# 99938    Male  55.0             0              1          former  30.42
# 99957  Female  61.0             0              0         No Info  34.45
# 99962  Female  58.0             1              0           never  38.31
# 99979  Female  61.0             0              0         current  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes
# 6              6.5                  200         1
# ...

# %%
df_no_diabetes = df[ df["diabetes"] == 0]
df_no_diabetes
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df[['diabetes']].value_counts()
# Out:
# diabetes
# 0           91500
# 1            8500
# Name: count, dtype: int64

# %%
print("Mean of Ages")
print("Total:", df["age"].mean())
print("No Diabetes:", df_no_diabetes["age"].mean())
print("Diabetes:", df_diabetes["age"].mean())
# Out:
# Mean of Ages
# Total: 41.885856
# No Diabetes: 40.115186885245905
# Diabetes: 60.946588235294115

# %%
df["smoking_history"].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
df_no_diabetes["smoking_history"].value_counts()
# Out:
# smoking_history
# No Info        34362
# never          31749
# current         8338
# former          7762
# not current     5757
# ever            3532
# Name: count, dtype: int64

# %%
df_diabetes["smoking_history"].value_counts()
# Out:
# smoking_history
# never          3346
# former         1590
# No Info        1454
# current         948
# not current     690
# ever            472
# Name: count, dtype: int64

# %%
df_little = df[ df["age"] < 10 ]
df_little["diabetes"].value_counts()
# Out:
#        gender  age  hypertension  heart_disease smoking_history    bmi  \
# 5092   Female  4.0             0              0         No Info  14.99
# 6566   Female  9.0             0              0           never  16.00
# 7987     Male  6.0             0              0           never  15.69
# 14275  Female  9.0             0              0         No Info  21.29
# 22000  Female  8.0             0              0         No Info  14.32
# 29893    Male  3.0             0              0         No Info  27.32
# 32160    Male  4.0             0              0           never  18.70
# 40352    Male  6.0             0              0         No Info  15.63
# 43269  Female  6.0             0              0         No Info  27.32
# 44678  Female  7.0             0              0         No Info  20.23
# 48089  Female  4.0             0              0           never  15.13
# 51774  Female  7.0             0              0           never  17.91
# ...

# %%
df_little_diabetes = df_little[ df_little["diabetes"] == 1]
df_little_diabetes["blood_glucose_level"].mean()
# Out:
# 215.63636363636363

# %%
df_little_no_diabetes = df_little[ df_little["diabetes"] == 0]
df_little_no_diabetes["blood_glucose_level"].mean()
# Out:
# 132.62022587268993
